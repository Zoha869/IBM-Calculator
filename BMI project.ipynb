# %%
name=input("Enter your name: ")
weight=float(input("Enter your weight in kg: "))
height=float(input("Enter your height in meters: "))
bmi = weight / (height ** 2)
print(f"Your {name} BMI is: {bmi:.2f}")
if bmi>0:
    if bmi<18.5:
        print("{name},you are Underweight.")
    elif bmi<=24.5:
        print("{name}your Weight is Normal.")
    elif bmi<29.9:
        print("{name},you are overweight,You need to exercise more.")
    elif bmi<34.9:
        print("{name},you are obese.")
    elif bmi<39.9:
        print("{name},you are severely obese.")
    else:
        print("{name},you are  morbidly obese.")
else:
    print("Enter valid number for input")
# Out:
# Enter your name:  zoha
# Enter your weight in kg:  50
# Enter your height in meters:  5.5
# Your zoha BMI is: 1.65
# {name},you are Underweight.
